# %% [markdown]
# <a href="https://colab.research.google.com/github/synapbyte-GK/README.md/blob/main/AIpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **First code**

# %%
print("Hello, World!")
